# %% [markdown]
# <a href="https://colab.research.google.com/github/allanzim/treinamento/blob/master/Day_4_Allan_Furukawa_Gadani.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install sidetable

import numpy as np
import pandas as pd

import sidetable
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df = pd.read_csv('/content/nyflights.csv')

df
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0                1  2013      1    1     517.0             515        2.0
# 1                2  2013      1    1     533.0             529        4.0
# 2                3  2013      1    1     542.0             540        2.0
# 3                4  2013      1    1     544.0             545       -1.0
# 4                5  2013      1    1     554.0             600       -6.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 308309      308310  2013      8   30    1818.0            1815        3.0
# 308310      308311  2013      8   30    1819.0            1545      154.0
# 308311      308312  2013      8   30    1819.0            1800       19.0
# 308312      308313  2013      8   30    1820.0            1748       32.0
# 308313      308314  2013      8   30    1820.0            1700       80.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
df_delay2hours = df[df['dep_delay']>2]

df_delay2hours
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 1                2  2013      1    1     533.0             529        4.0
# 25              26  2013      1    1     608.0             600        8.0
# 26              27  2013      1    1     611.0             600       11.0
# 27              28  2013      1    1     613.0             610        3.0
# 31              32  2013      1    1     623.0             610       13.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 308309      308310  2013      8   30    1818.0            1815        3.0
# 308310      308311  2013      8   30    1819.0            1545      154.0
# 308311      308312  2013      8   30    1819.0            1800       19.0
# 308312      308313  2013      8   30    1820.0            1748       32.0
# 308313      308314  2013      8   30    1820.0            1700       80.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
df[df['dep_delay']>2].dest.value_counts()
# Out:
# ORD    5321
# LAX    5037
# ATL    5002
# SFO    4555
# MCO    4505
#        ...
# CHO       8
# EYW       6
# ANC       5
# SBN       4
# PSP       3
# Name: dest, Length: 103, dtype: int64

# %%
the_piores = df_delay2hours[df_delay2hours['dep_time']-df_delay2hours['sched_dep_time']>=5]

the_piores
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 25              26  2013      1    1     608.0             600        8.0
# 26              27  2013      1    1     611.0             600       11.0
# 31              32  2013      1    1     623.0             610       13.0
# 41              42  2013      1    1     632.0             608       24.0
# 47              48  2013      1    1     644.0             636        8.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 308306      308307  2013      8   30    1817.0            1810        7.0
# 308310      308311  2013      8   30    1819.0            1545      154.0
# 308311      308312  2013      8   30    1819.0            1800       19.0
# 308312      308313  2013      8   30    1820.0            1748       32.0
# 308313      308314  2013      8   30    1820.0            1700       80.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
premissas_do_japinha = the_piores.sort_values(by=['dest'])

premissas_do_japinha.dest.value_counts().head(5)
# Out:
# ORD    4875
# ATL    4602
# LAX    4373
# SFO    4045
# MCO    4040
# Name: dest, dtype: int64

# %%
df['dep_delay'].describe()
# Out:
# count    300521.000000
# mean         13.189112
# std          40.583097
# min         -43.000000
# 25%          -5.000000
# 50%          -1.000000
# 75%          12.000000
# max        1301.000000
# Name: dep_delay, dtype: float64

# %%
df_delay2hours
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 1                2  2013      1    1     533.0             529        4.0
# 25              26  2013      1    1     608.0             600        8.0
# 26              27  2013      1    1     611.0             600       11.0
# 27              28  2013      1    1     613.0             610        3.0
# 31              32  2013      1    1     623.0             610       13.0
# ...            ...   ...    ...  ...       ...             ...        ...
# 308309      308310  2013      8   30    1818.0            1815        3.0
# 308310      308311  2013      8   30    1819.0            1545      154.0
# 308311      308312  2013      8   30    1819.0            1800       19.0
# 308312      308313  2013      8   30    1820.0            1748       32.0
# 308313      308314  2013      8   30    1820.0            1700       80.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# ...

# %%
(df_delay2hours['arr_time']-df_delay2hours['dep_time'])/df_delay2hours['air_time']
# Out:
# 1          1.396476
# 25         1.431655
# 26         0.912568
# 27         1.782857
# 31         1.941176
#             ...
# 336759     0.515464
# 336760     1.066667
# 336762    -6.669811
# 336763   -17.691057
# 336768     1.575758
# Length: 114149, dtype: float64

# %%
velocidade = df_delay2hours['distance']/df_delay2hours['air_time']
# Out:
# 1         6.237885
# 25        5.172662
# 26        7.065574
# 27        6.137143
# 31        7.163399
#             ...
# 336759    7.876289
# 336760    7.266667
# 336762    8.066038
# 336763    7.674797
# 336768    5.666667
# Length: 114149, dtype: float64
